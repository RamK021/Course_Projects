# %%
import pandas as pd

# %%
df = pd.read_csv("city_day.csv")
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
data = df.copy()
data
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
data.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
data['AQI_Bucket'].value_counts()
# Out:
# AQI_Bucket
# Moderate        8829
# Satisfactory    8224
# Poor            2781
# Very Poor       2337
# Good            1341
# Severe          1338
# Name: count, dtype: int64

# %%
data['AQI_Bucket'].mode()
# Out:
# 0    Moderate
# Name: AQI_Bucket, dtype: object

# %%
data = data.apply(lambda x:x.fillna(x.median())
                            if x.dtype == 'float'
                            else x.fillna(x.mode()[0]))

# %%
data
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01  48.57  95.68   0.92  18.22  17.15  15.85
# 1          Ahmedabad  2015-01-02  48.57  95.68   0.97  15.69  16.46  15.85
# 2          Ahmedabad  2015-01-03  48.57  95.68  17.40  19.30  29.70  15.85
# 3          Ahmedabad  2015-01-04  48.57  95.68   1.70  18.48  17.97  15.85
# 4          Ahmedabad  2015-01-05  48.57  95.68  22.10  21.42  37.76  15.85
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
data.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
airAQI     = (data['AQI_Bucket'])
airAQISet  = set(airAQI)
airAQIList = list(airAQISet)
dic1       = {airAQIList[i]:i for i in range(len(airAQISet))}
data['AQI_Bucket'] = data['AQI_Bucket'].map(dic1)

# %%
airCity     = (data['City'])
airCitySet  = set(airCity)
airCityList = list(airCitySet)
dic2       = {airCityList[i]:i for i in range(len(airCitySet))}
data['City'] = data['City'].map(dic2)

# %%
data.head()
# Out:
#    City        Date  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2  \
# 0    24  2015-01-01  48.57  95.68   0.92  18.22  17.15  15.85   0.92  27.64
# 1    24  2015-01-02  48.57  95.68   0.97  15.69  16.46  15.85   0.97  24.55
# 2    24  2015-01-03  48.57  95.68  17.40  19.30  29.70  15.85  17.40  29.07
# 3    24  2015-01-04  48.57  95.68   1.70  18.48  17.97  15.85   1.70  18.59
# 4    24  2015-01-05  48.57  95.68  22.10  21.42  37.76  15.85  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene    AQI  AQI_Bucket
# 0  133.36     0.00     0.02    0.00  118.0           4
# 1   34.06     3.68     5.50    3.77  118.0           4
# 2   30.70     6.80    16.40    2.25  118.0           4
# 3   36.08     4.43    10.14    1.00  118.0           4
# 4   39.31     7.01    18.89    2.78  118.0           4

# %%
import matplotlib.pyplot as plt
import sklearn

# %%
indep = data[['City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']]
indep.head()
# Out:
#    City  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2      O3  \
# 0    24  48.57  95.68   0.92  18.22  17.15  15.85   0.92  27.64  133.36
# 1    24  48.57  95.68   0.97  15.69  16.46  15.85   0.97  24.55   34.06
# 2    24  48.57  95.68  17.40  19.30  29.70  15.85  17.40  29.07   30.70
# 3    24  48.57  95.68   1.70  18.48  17.97  15.85   1.70  18.59   36.08
# 4    24  48.57  95.68  22.10  21.42  37.76  15.85  22.10  39.33   39.31
#
#    Benzene  Toluene  Xylene
# 0     0.00     0.02    0.00
# 1     3.68     5.50    3.77
# 2     6.80    16.40    2.25
# 3     4.43    10.14    1.00
# 4     7.01    18.89    2.78

# %%
dep = data[['AQI']]
dep.head()
# Out:
#      AQI
# 0  118.0
# 1  118.0
# 2  118.0
# 3  118.0
# 4  118.0

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(indep, dep, test_size=0.2, random_state=42, shuffle=True)

# %%
train_data = pd.concat([x_train, y_train], axis='columns',
                names = ['City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI_Bucket', 'AQI'])

# %%
train_data.head()
# Out:
#        City   PM2.5    PM10     NO    NO2    NOx    NH3    CO    SO2     O3  \
# 6688     15  142.27  252.49  17.11  33.82  50.91   9.80  4.36  17.18  17.68
# 29333    25   75.61  121.94   2.95  27.03  16.78  15.92  1.12   8.24  74.21
# 27996    14   15.01   27.65   3.25   7.99   9.71   6.01  0.48   5.80  29.78
# 26848    16   48.57   95.68   9.89  21.69  23.52  15.85  0.89   9.16  30.84
# 21186     7   16.66   95.68   7.44  28.00  23.79  28.83  0.82   5.03  14.32
#
#        Benzene  Toluene  Xylene    AQI
# 6688      0.00     2.97    0.98  325.0
# 29333     4.93     7.53    1.13  128.0
# 27996     1.07     2.97    0.98   46.0
# 26848     1.07     2.97    0.98  118.0
# 21186     0.09     0.21    0.98   69.0

# %%
corr_matrix = train_data.corr(method = 'pearson')
corr_matrix
# Out:
#              City     PM2.5      PM10        NO       NO2       NOx       NH3  \
# City     1.000000 -0.053119 -0.139044 -0.011155  0.106919 -0.005601 -0.141643
# PM2.5   -0.053119  1.000000  0.515269  0.431047  0.355669  0.369906  0.166548
# PM10    -0.139044  0.515269  1.000000  0.431444  0.353222  0.415708  0.205708
# NO      -0.011155  0.431047  0.431444  1.000000  0.471985  0.742645  0.158384
# NO2      0.106919  0.355669  0.353222  0.471985  1.000000  0.580080  0.158494
# NOx     -0.005601  0.369906  0.415708  0.742645  0.580080  1.000000  0.134726
# NH3     -0.141643  0.166548  0.205708  0.158384  0.158494  0.134726  1.000000
# CO       0.239528  0.095644  0.024393  0.229988  0.360178  0.234985 -0.013627
# SO2      0.193103  0.120182  0.162892  0.177794  0.389762  0.207419 -0.048949
# O3      -0.014684  0.166253  0.214794  0.019667  0.291753  0.094001  0.080790
# Benzene  0.034670  0.025877  0.023743  0.041461  0.034671  0.043822  0.005197
# ...

# %%
plt.matshow(corr_matrix)
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.colorbar()
plt.show()

# %%
plt.scatter(x_train['PM2.5'], y_train)
plt.title('PM2.5 vs AQI')
plt.xlabel('PM2.5')
plt.ylabel('AQI')
plt.plot()
# Out:
# []

# %%
plt.scatter(x_train['PM10'], y_train)
plt.title('PM10 vs AQI')
plt.xlabel('PM10')
plt.ylabel('AQI')
plt.plot()
# Out:
# []

# %%
plt.scatter(x_train['City'], y_train)
plt.title('City vs AQI')
plt.xlabel('City')
plt.ylabel('AQI')
plt.plot()
# Out:
# []

# %%
plt.scatter(x_train['CO'], y_train)
plt.title('CO vs AQI')
plt.xlabel('CO')
plt.ylabel('AQI')
plt.plot()
# Out:
# []

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()

model.fit(x_train, y_train)
y_pred_train = model.predict(x_train)
y_pred = model.predict(x_test)
# Out:
# C:\Users\shyam\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mse_train = mean_squared_error(y_train, y_pred_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)

# Print the evaluation metrics on train data
print("Evaluation metrics: Train Data")
print("Mean absolute error:", mae_train)
print("Mean squared error :", mse_train)
print("R-squared score    :", r2_train)
# Out:
# Evaluation metrics: Train Data
# Mean absolute error: 7.6728817074562174
# Mean squared error : 323.9651622328711
# R-squared score    : 0.9813430950011848

# %%
mse_test = mean_squared_error(y_test, y_pred)
mae_test = mean_absolute_error(y_test, y_pred)
r2_test = r2_score(y_test, y_pred)

# Print the evaluation metrics on test data
print("Evaluation metrics: Test Data")
print("Mean absolute error:", mae_test)
print("Mean squared error :", mse_test)
print("R-squared score    :", r2_test)
# Out:
# Evaluation metrics: Test Data
# Mean absolute error: 20.032073778572627
# Mean squared error : 1929.1137444696317
# R-squared score    : 0.8746878158915555

# %%
dic = {}
for key, value in dic2.items():
    dic[value] = key

dic
# Out:
# {0: 'Ernakulam',
#  1: 'Delhi',
#  2: 'Jorapokhar',
#  3: 'Mumbai',
#  4: 'Hyderabad',
#  5: 'Amritsar',
#  6: 'Coimbatore',
#  7: 'Lucknow',
#  8: 'Chennai',
#  9: 'Shillong',
#  10: 'Amaravati',
#  11: 'Guwahati',
#  12: 'Gurugram',
#  13: 'Bengaluru',
#  14: 'Thiruvananthapuram',
#  15: 'Brajrajnagar',
#  16: 'Talcher',
#  17: 'Aizawl',
#  18: 'Patna',
#  19: 'Kolkata',
#  20: 'Kochi',
#  21: 'Jaipur',
#  22: 'Chandigarh',
#  23: 'Bhopal',
#  24: 'Ahmedabad',
#  25: 'Visakhapatnam'}

# %%
def predict_aqi():
    city = int(input("Enter City       : "))
    pm25 = float(input("Enter PM2.5 value: "))
    pm10 = float(input("Enter PM10 value : "))
    no   = float(input("Enter NO value   : "))
    no2  = float(input("Enter NO2 value  : "))
    nox  = float(input("Enter NOx value  : "))
    nh3  = float(input("Enter NH3 value  : "))
    co   = float(input("Enter CO value   : "))
    so2  = float(input("Enter SO2 value  : "))
    o3   = float(input("Enter O3 value   : "))
    benzene = float(input("Enter Benzene value: "))
    toluene = float(input("Enter Toluene value: "))
    xylene  = float(input("Enter Xylene value : "))

    # Create a new DataFrame with user input data
    new_data = pd.DataFrame({
        'City': [city],
        'PM2.5': [pm25],
        'PM10': [pm10],
        'NO': [no],
        'NO2': [no2],
        'NOx': [nox],
        'NH3': [nh3],
        'CO': [co],
        'SO2': [so2],
        'O3': [o3],
        'Benzene': [benzene],
        'Toluene': [toluene],
        'Xylene': [xylene]
    })
    predicted_aqi = model.predict(new_data)
    
    
    if 0<= predicted_aqi[0]<=50:
        print(f"Predicted AQI of {dic[city]}:", predicted_aqi[0],"is Good!")
    elif 50< predicted_aqi[0]<=100:
        print(f"Predicted AQI of {dic[city]}:", predicted_aqi[0],"is Satisfactory!")
    elif 100< predicted_aqi[0]<=200:
        print(f"Predicted AQI of {dic[city]}:", predicted_aqi[0],"is Moderate!")
    elif 200< predicted_aqi[0]<=300:
        print(f"Predicted AQI of {dic[city]}:", predicted_aqi[0],"is Poor!")
    elif 300< predicted_aqi[0]<=400:
        print(f"Predicted AQI of {dic[city]}:", predicted_aqi[0],"is Very Poor!")
    else:
        print(f"Predicted AQI of {dic[city]}:", predicted_aqi[0],"is Severe!")
        
#predict_aqi()

# %%
import pickle

with open('model.pkl', 'wb') as files:
    pickle.dump(model, files)

with open('dic.pkl', 'wb') as files:
    pickle.dump(dic, files)
